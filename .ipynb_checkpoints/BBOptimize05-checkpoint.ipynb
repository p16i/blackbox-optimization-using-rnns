# %% [markdown]
# ## Global Black Box Optimization with RNNS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 1.1.0

# %%
def poly(a,b,c,x):
    return a*(x-b)**2+c

def min_poly(a,b,c):
    return b, c

# %%
def gen_data(n_train, n_test):
    a_train = np.random.uniform(size=(n_train,1),low = 0.5, high = 5.0)
    b_train = np.random.uniform(size=(n_train,1),low = -3.0, high = 3.0)
    c_train = np.random.uniform(size=(n_train,1),low = -2.0, high = 2.0)
    
    a_test = np.random.uniform(size=(n_test,1),low = 0.5, high = 5.0)
    b_test = np.random.uniform(size=(n_test,1),low = -3.0, high = 3.0)
    c_test = np.random.uniform(size=(n_test,1),low = -2.0, high = 2.0)
    
    return (a_train, b_train, c_train, a_test, b_test, c_test)

# %%
# Number of Traing/Test examples
n_train = 100
n_test = 100

# Number of hidden states in RNN cell
n_hidden = 10

# Sequence length
num_steps = 10

# Generate Training Data
a_train, b_train, c_train, a_test, b_test, c_test = gen_data(n_train, n_test)

# %%
# Create RNN Cell
# x, h = RNN(x, y, h)

variable_dict = {"W1": tf.Variable(tf.truncated_normal([1 + 1 + n_hidden, 30],stddev=0.05)),\
                  "b1": tf.Variable(tf.zeros([30])),\
                  "W2": tf.Variable(tf.truncated_normal([30, 1 + n_hidden],stddev=0.05)),\
                  "b2": tf.Variable(tf.zeros([1 + n_hidden]))}


def rnn_cell(x, y, h, v_dict):
    z = tf.matmul(tf.nn.tanh(tf.matmul(tf.concat([x, y, h], 1),\
                                       v_dict["W1"]) + v_dict["b1"]), v_dict["W2"]) + v_dict["b2"]
        
    return tf.split(z,[1, n_hidden],axis=1)

# %%
# Create Model

size = tf.placeholder(tf.int32,[])

a = tf.placeholder(tf.float32, [None, 1])
b = tf.placeholder(tf.float32, [None, 1])
c = tf.placeholder(tf.float32, [None, 1])

x_0 = 3.5*tf.ones([size, 1])
h_0 = tf.truncated_normal([size, n_hidden],stddev=0.1)

h = h_0
x = x_0
y = poly(a,b,c,x)
sample_points = [x]
f_sum = 0
f_min = y
for i in range(num_steps):
    
    x, h = rnn_cell(x, y, h, variable_dict)
    sample_points.append(x)
    y = poly(a,b,c,x)
    
    f_sum += tf.reduce_mean(y-f_min)/num_steps
    f_min = tf.minimum(y, f_min)

# %%
train_rate = tf.placeholder(tf.float32,[])
#train_step = tf.train.AdamOptimizer(train_rate).minimize(f_sum)
train_step = tf.train.AdagradOptimizer(0.1).minimize(f_sum)
#train_step = tf.train.GradientDescentOptimizer(1.0).minimize(f_out)
# Out:
# [<tf.Tensor 'gradients_2/split_29_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_28_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_27_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_26_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_25_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_24_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_23_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_22_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_21_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]
# [<tf.Tensor 'gradients_2/split_20_grad/concat:0' shape=(?, 11) dtype=float32>, None, None]

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

# %%
# Train the Network
train_loss_list = []
test_loss_list = []

epochs = 10000
batch_size = 100

for ep in range(epochs):
    for batch in range(n_train//batch_size):
        a_batch = a_train[batch*batch_size:(batch+1)*batch_size]
        b_batch = b_train[batch*batch_size:(batch+1)*batch_size]
        c_batch = c_train[batch*batch_size:(batch+1)*batch_size]
        
        sess.run([train_step], feed_dict={a: a_batch, b: b_batch, c: c_batch, train_rate:0.001, size: batch_size})
    
    train_loss_list += [sess.run([f_sum], feed_dict={a: a_train, b: b_train, c: c_train, size : n_train})]
    test_loss_list += [sess.run([f_sum], feed_dict={a: a_test, b: b_test, c: c_test, size:n_test})]
    
    if ep % 1000 == 0 or ep == epochs-1:
        print("Epoch: " +str(ep)+" Training loss: "+str(train_loss_list[-1])+ " Test loss: "+str(test_loss_list[-1]))
    
# Extract Samples
samples = sess.run([sample_points], feed_dict={a: a_train, b: b_train, c: c_train, size: n_train})
samples = np.array(samples[0]).reshape(num_steps+1,n_train).T
# Out:
# Epoch: 0 Training loss: [-1.0059893] Test loss: [0.82883155]
# Epoch: 1000 Training loss: [-2.3261964] Test loss: [-1.426011]
# Epoch: 2000 Training loss: [-3.9006743] Test loss: [-3.0968628]
# Epoch: 3000 Training loss: [-3.9342191] Test loss: [-3.1293156]
# Epoch: 4000 Training loss: [-3.942708] Test loss: [-3.1468897]
# Epoch: 5000 Training loss: [-3.9498658] Test loss: [-3.1528375]
# Epoch: 6000 Training loss: [-3.9558129] Test loss: [-3.1530447]
# Epoch: 7000 Training loss: [-3.9473457] Test loss: [-3.1433227]
# Epoch: 8000 Training loss: [-3.9577868] Test loss: [-3.156188]
# Epoch: 9000 Training loss: [-3.960108] Test loss: [-3.1522052]
# Epoch: 9999 Training loss: [-3.9618101] Test loss: [-3.1592684]

# %%
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.plot(train_loss_list)
plt.title("Training Error")
plt.subplot(1,2,2)
plt.plot(test_loss_list)
plt.title("Validation Error")
plt.show()

# %%
def plot_result(traintest="train"): 
    if traintest == "train":
        a, b ,c = (a_train, b_train, c_train)
        i = np.random.randint(n_train)
    else:
        a, b ,c = (a_test, b_test, c_test)
        i = np.random.randint(n_test)
        
    annotation = list(range(num_steps+1))
    xx = np.linspace(-4,4,200)
    yy = poly(a[i],b[i],c[i],xx)

    samples_x = samples[i]
    samples_y = poly(a[i],b[i],c[i],samples_x)
    
    x_min, y_min = min_poly(a[i],b[i],c[i])

    fig, ax = plt.subplots(figsize=(20,10))
    ax.plot(xx,yy,linewidth=3)
    ax.scatter(samples_x,samples_y)
    ax.scatter(x_min, y_min, marker='x', linewidth = 30)
    for i, txt in enumerate(annotation):
        ax.annotate(str(txt), (samples_x[i],samples_y[i]),\
                    xytext=(samples_x[i]+np.random.uniform(-1,1),\
                            samples_y[i]+3.0), arrowprops=dict(facecolor='black', shrink=0.01))
    plt.show()
    print(samples_x)
    print(x_min)

plot_result("test")
# Out:
# [ 3.5         3.44909215  2.69802928  2.54103923  2.43952584  2.44284749
#   2.43151641  2.42747188  2.42645597  2.42628169  2.42626572]
# [ 1.98592439]
