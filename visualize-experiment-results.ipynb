# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import utils
import glob
import re
import pandas as pd

# %%
def string_to_number(st):
    stt = re.sub('^-','',st)
    if re.match('^\d+$', stt):
        return int(st)
    elif re.match('[\d\.]+',stt):
        return float(st)
    return st
assert(string_to_number('123123') == 123123)
assert(string_to_number('-123123') == -123123)
assert(string_to_number('0.2123123') == 0.2123123)
assert(string_to_number('-0.21123') == -0.21123)

# %%
def extract_output(log_dir):

    config = utils.loadConfig()
    path = config['BASE_LOG_DIR'] + '/' + log_dir + '/*'

    files = glob.glob(path)
    no_files = len(files)
    print('Found %d files in %s' % (no_files, path))

    results = []
    for fp in files:
        with open(fp) as f:
            columns = dict()
            lines = f.readlines()
            hyper_block = False
            for line in lines:
                reg_ex = '^-+'
                if re.match(reg_ex, line):
                    hyper_block = not hyper_block
                    
                if hyper_block and not re.match(reg_ex, line):
                    k,v = re.split(" *: +", line.strip())
                    columns[k] = string_to_number(v)
    
            last_lines = lines[-2].replace("Last output: ","")
            
            for t in last_lines.split('|'):
                k,v = re.split(" *: +", t.strip())
                columns[k] = string_to_number(v)
            results.append(columns)
    return pd.DataFrame(results)

# %%
show_columns = ['RNN Scope','Number of hidden Units','Loss','TestLoss','TestMin', 'TrainMin']

# %%
extract_output("2d")[show_columns].sort_values('TestMin')
# Out:
# Found 28 files in ./log/2d/*
#                  RNN Scope  Number of hidden Units        Loss  TestLoss  \
# 3   rnn-cell-2d-1497731697                     100         MIN    -0.924
# 2   rnn-cell-2d-1497731360                      60         MIN    -0.955
# 0   rnn-cell-2d-1497730689                      10         MIN    -0.947
# 1   rnn-cell-2d-1497731024                      30         MIN    -0.944
# 26  rnn-cell-2d-1497781350                      60  OI_UPDATED    -0.925
# 27  rnn-cell-2d-1497781757                     100  OI_UPDATED    -0.923
# 19  rnn-cell-2d-1497737347                     100      SUMMIN   -13.919
# 18  rnn-cell-2d-1497737004                      60      SUMMIN   -13.537
# 7   rnn-cell-2d-1497733046                     100         SUM   -12.771
# 11  rnn-cell-2d-1497734400                     100        WSUM    -6.777
# 22  rnn-cell-2d-1497738360                      60   WSUM_EXPO    -0.595
# 10  rnn-cell-2d-1497734059                      60        WSUM    -6.873
# 25  rnn-cell-2d-1497780941                      30  OI_UPDATED    -0.889
# 23  rnn-cell-2d-1497738698                     100   WSUM_EXPO    -0.593
# 17  rnn-cell-2d-1497736663                      30      SUMMIN   -13.067
# 9   rnn-cell-2d-1497733722                      30        WSUM    -6.416
# 21  rnn-cell-2d-1497738027                      30   WSUM_EXPO    -0.581
# 24  rnn-cell-2d-1497780517                      10  OI_UPDATED    -0.864
# 5   rnn-cell-2d-1497732367                      30         SUM   -12.020
# 6   rnn-cell-2d-1497732707                      60         SUM   -12.217
# 20  rnn-cell-2d-1497737690                      10   WSUM_EXPO    -0.487
# 16  rnn-cell-2d-1497736321                      10      SUMMIN   -10.393
# 4   rnn-cell-2d-1497732032                      10         SUM    -8.262
# 8   rnn-cell-2d-1497733384                      10        WSUM    -4.332
# 15  rnn-cell-2d-1497735924                     100          OI     4.817
# 14  rnn-cell-2d-1497735527                      60          OI     7.516
# 13  rnn-cell-2d-1497735129                      30          OI     8.291
# 12  rnn-cell-2d-1497734734                      10          OI     0.199
#
#     TestMin  TrainMin
# 3    -0.968    -0.993
# 2    -0.960    -0.980
# 0    -0.958    -0.932
# 1    -0.950    -0.960
# 26   -0.933    -0.964
# 27   -0.922    -0.937
# 19   -0.917    -0.928
# 18   -0.911    -0.921
# 7    -0.900    -0.899
# 11   -0.900    -0.902
# 22   -0.898    -0.896
# 10   -0.894    -0.900
# 25   -0.885    -0.874
# 23   -0.883    -0.873
# 17   -0.880    -0.864
# 9    -0.879    -0.856
# 21   -0.873    -0.863
# 24   -0.861    -0.833
# 5    -0.855    -0.843
# 6    -0.853    -0.860
# 20   -0.778    -0.745
# 16   -0.703    -0.660
# 4    -0.565    -0.532
# 8    -0.560    -0.529
# 15   -0.416    -0.369
# 14   -0.351    -0.318
# 13   -0.263    -0.232
# 12   -0.258    -0.224

# %% [markdown]
# # 3d Models

# %%
extract_output("3d-rbf")[show_columns].sort_values('TestMin')[:10]
# Out:
# Found 8 files in ./log/3d-rbf/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-3d-1498175944                      60        MIN    -0.839
# 1  rnn-cell-3d-1498176338                     100        MIN    -0.840
# 6  rnn-cell-3d-1498178416                      60  WSUM_EXPO    -0.524
# 5  rnn-cell-3d-1498178016                     100     SUMMIN   -11.741
# 4  rnn-cell-3d-1498177616                      60     SUMMIN   -11.727
# 7  rnn-cell-3d-1498178812                     100  WSUM_EXPO    -0.454
# 2  rnn-cell-3d-1498176732                      60         OI    -0.734
# 3  rnn-cell-3d-1498177173                     100         OI    -0.595
#
#    TestMin  TrainMin
# 0   -0.848    -0.969
# 1   -0.848    -0.972
# 6   -0.839    -0.908
# 5   -0.801    -0.915
# 4   -0.788    -0.891
# 7   -0.776    -0.901
# 2   -0.752    -0.825
# 3   -0.610    -0.641

# %%
extract_output("3d-matern32")[show_columns].sort_values('TestMin')[:5]
# Out:
# Found 8 files in ./log/3d-matern32/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 5  rnn-cell-3d-1498181506                     100     SUMMIN   -11.930
# 0  rnn-cell-3d-1498179215                      60        MIN    -0.874
# 7  rnn-cell-3d-1498182372                     100  WSUM_EXPO    -0.527
# 1  rnn-cell-3d-1498179654                     100        MIN    -0.799
# 4  rnn-cell-3d-1498181075                      60     SUMMIN   -10.171
#
#    TestMin  TrainMin
# 5   -0.880    -0.938
# 0   -0.877    -0.923
# 7   -0.863    -0.899
# 1   -0.801    -0.900
# 4   -0.753    -0.841

# %%
extract_output("3d-matern52")[show_columns].sort_values('TestMin')[:5]
# Out:
# Found 8 files in ./log/3d-matern52/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 1  rnn-cell-3d-1498183322                     100        MIN    -0.857
# 0  rnn-cell-3d-1498182808                      60        MIN    -0.782
# 7  rnn-cell-3d-1498186525                     100  WSUM_EXPO    -0.452
# 4  rnn-cell-3d-1498184965                      60     SUMMIN    -9.244
# 6  rnn-cell-3d-1498186009                      60  WSUM_EXPO    -0.399
#
#    TestMin  TrainMin
# 1   -0.858    -0.910
# 0   -0.784    -0.893
# 7   -0.724    -0.836
# 4   -0.696    -0.801
# 6   -0.675    -0.739

# %% [markdown]
# # 4d Models

# %%
extract_output("4d-rbf")[show_columns].sort_values('TestMin')[:5]
# Out:
# Found 8 files in ./log/4d-rbf/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 1  rnn-cell-4d-1498250543                     100        MIN    -0.777
# 0  rnn-cell-4d-1498250146                      60        MIN    -0.789
# 5  rnn-cell-4d-1498252230                     100     SUMMIN   -10.194
# 7  rnn-cell-4d-1498253030                     100  WSUM_EXPO    -0.396
# 4  rnn-cell-4d-1498251827                      60     SUMMIN   -10.139
#
#    TestMin  TrainMin
# 1   -0.801    -1.048
# 0   -0.798    -0.952
# 5   -0.747    -0.965
# 7   -0.745    -0.937
# 4   -0.744    -0.887

# %%
extract_output("4d-matern32")[show_columns].sort_values('TestMin')[:5]
# Out:
# Found 8 files in ./log/4d-matern32/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 3  rnn-cell-4d-1498254809                     100         OI    -0.884
# 1  rnn-cell-4d-1498253875                     100        MIN    -0.845
# 2  rnn-cell-4d-1498254315                      60         OI    -0.734
# 7  rnn-cell-4d-1498256652                     100  WSUM_EXPO    -0.344
# 4  rnn-cell-4d-1498255305                      60     SUMMIN    -8.064
#
#    TestMin  TrainMin
# 3   -0.903    -0.995
# 1   -0.853    -1.115
# 2   -0.741    -0.893
# 7   -0.707    -1.046
# 4   -0.673    -0.894

# %%
extract_output("4d-matern52")[show_columns].sort_values('TestMin')[:5]
# Out:
# Found 8 files in ./log/4d-matern52/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 1  rnn-cell-4d-1498257618                     100        MIN    -0.827
# 7  rnn-cell-4d-1498260745                     100  WSUM_EXPO    -0.459
# 3  rnn-cell-4d-1498258692                     100         OI    -0.723
# 5  rnn-cell-4d-1498259742                     100     SUMMIN    -8.802
# 6  rnn-cell-4d-1498260243                      60  WSUM_EXPO    -0.357
#
#    TestMin  TrainMin
# 1   -0.835    -1.053
# 7   -0.829    -1.020
# 3   -0.738    -0.878
# 5   -0.725    -1.030
# 6   -0.682    -0.892

# %% [markdown]
# # 6d Models

# %%
extract_output("6d-rbf")[show_columns].sort_values('TestMin')[:5]
# Out:
# Found 8 files in ./log/6d-rbf/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 1  rnn-cell-6d-1498291713                     100        MIN    -0.929
# 0  rnn-cell-6d-1498291320                      60        MIN    -0.796
# 5  rnn-cell-6d-1498293398                     100     SUMMIN    -8.971
# 7  rnn-cell-6d-1498294196                     100  WSUM_EXPO    -0.310
# 2  rnn-cell-6d-1498292110                      60         OI    -0.671
#
#    TestMin  TrainMin
# 1   -0.955    -1.273
# 0   -0.813    -1.071
# 5   -0.733    -1.163
# 7   -0.709    -1.103
# 2   -0.691    -0.869

# %%
extract_output("6d-matern32")[show_columns].sort_values('TestMin')[:5]
# Out:
# Found 8 files in ./log/6d-matern32/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 1  rnn-cell-6d-1498295036                     100        MIN    -0.942
# 3  rnn-cell-6d-1498295967                     100         OI    -0.548
# 5  rnn-cell-6d-1498296907                     100     SUMMIN    -4.418
# 0  rnn-cell-6d-1498294597                      60        MIN    -0.434
# 7  rnn-cell-6d-1498297782                     100  WSUM_EXPO    -0.160
#
#    TestMin  TrainMin
# 1   -0.957    -1.616
# 3   -0.568    -1.070
# 5   -0.493    -1.297
# 0   -0.442    -0.877
# 7   -0.411    -0.821

# %%
extract_output("6d-matern52")[show_columns].sort_values('TestMin')
# Out:
# Found 8 files in ./log/6d-matern52/*
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 7  rnn-cell-6d-1498301947                     100  WSUM_EXPO    -0.211
# 1  rnn-cell-6d-1498298732                     100        MIN    -0.508
# 5  rnn-cell-6d-1498300906                     100     SUMMIN    -4.812
# 0  rnn-cell-6d-1498298215                      60        MIN    -0.471
# 3  rnn-cell-6d-1498299817                     100         OI    -0.442
# 4  rnn-cell-6d-1498300385                      60     SUMMIN    -3.823
# 2  rnn-cell-6d-1498299249                      60         OI    -0.411
# 6  rnn-cell-6d-1498301430                      60  WSUM_EXPO    -0.152
#
#    TestMin  TrainMin
# 7   -0.582    -1.317
# 1   -0.518    -1.166
# 5   -0.512    -1.220
# 0   -0.479    -0.962
# 3   -0.452    -0.996
# 4   -0.419    -0.865
# 2   -0.415    -0.748
# 6   -0.412    -0.814
