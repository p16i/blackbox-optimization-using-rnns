# %%
# %matplotlib inline

import utils

# %%
show_columns = ['RNN Scope','Number of hidden Units','Loss','TestLoss','TestMin', 'TrainMin']

# %% [markdown]
# # 1d Models

# %%
utils.extract_lstm_trained_output("1d-rbf")[show_columns].sort_values('TestMin')
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-1d-1498478841                     100        MIN    -1.005
# 2  rnn-cell-1d-1498479668                     100     SUMMIN   -15.720
# 1  rnn-cell-1d-1498479230                     100         OI    -0.985
# 3  rnn-cell-1d-1498480063                     100  WSUM_EXPO    -0.668
# 4  rnn-cell-1d-1499499735                     100        SUM   -13.789
#
#    TestMin  TrainMin
# 0   -1.017    -1.023
# 2   -1.014    -1.012
# 1   -0.988    -0.991
# 3   -0.958    -0.963
# 4   -0.890    -0.905

# %%
utils.extract_lstm_trained_output("1d-matern32")[show_columns].sort_values('TestMin')
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-1d-1498480459                     100        MIN    -0.996
# 4  rnn-cell-1d-1499500063                     100        SUM   -13.246
# 2  rnn-cell-1d-1498481395                     100     SUMMIN   -14.052
# 3  rnn-cell-1d-1498481844                     100  WSUM_EXPO    -0.496
# 1  rnn-cell-1d-1498480902                     100         OI    -0.458
#
#    TestMin  TrainMin
# 0   -0.998    -1.001
# 4   -0.933    -0.935
# 2   -0.924    -0.924
# 3   -0.784    -0.779
# 1   -0.474    -0.472

# %% [markdown]
# # 2d models

# %%
utils.extract_lstm_trained_output("2d-rbf")[show_columns].sort_values('TestMin')
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-2d-1498485717                     100        MIN    -0.947
# 1  rnn-cell-2d-1498486433                     100         OI    -0.926
# 2  rnn-cell-2d-1498487245                     100     SUMMIN   -13.529
# 3  rnn-cell-2d-1498487978                     100  WSUM_EXPO    -0.608
# 4  rnn-cell-2d-1499500405                     100        SUM   -13.030
#
#    TestMin  TrainMin
# 0   -0.950    -0.996
# 1   -0.912    -0.961
# 2   -0.893    -0.909
# 3   -0.878    -0.889
# 4   -0.865    -0.890

# %%
utils.extract_lstm_trained_output("2d-matern32")[show_columns].sort_values('TestMin')
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-2d-1498488698                     100        MIN    -0.881
# 1  rnn-cell-2d-1498489510                     100         OI    -0.781
# 2  rnn-cell-2d-1498490418                     100     SUMMIN    -7.272
# 4  rnn-cell-2d-1499501091                     100        SUM    -7.553
# 3  rnn-cell-2d-1498491255                     100  WSUM_EXPO    -0.361
#
#    TestMin  TrainMin
# 0   -0.882    -0.896
# 1   -0.776    -0.780
# 2   -0.540    -0.543
# 4   -0.533    -0.536
# 3   -0.505    -0.507

# %% [markdown]
# # 3d Models

# %%
utils.extract_lstm_trained_output("3d-rbf")[show_columns].sort_values('TestMin')[:10]
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-3d-1498492074                     100        MIN    -0.917
# 1  rnn-cell-3d-1498493139                     100         OI    -0.890
# 2  rnn-cell-3d-1498494334                     100     SUMMIN   -13.878
# 3  rnn-cell-3d-1498495416                     100  WSUM_EXPO    -0.617
# 4  rnn-cell-3d-1499501850                     100        SUM   -12.563
#
#    TestMin  TrainMin
# 0   -0.919    -0.970
# 1   -0.888    -0.912
# 2   -0.884    -0.906
# 3   -0.883    -0.906
# 4   -0.848    -0.897

# %%
utils.extract_lstm_trained_output("3d-matern32")[show_columns].sort_values('TestMin')[:5]
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-3d-1498496490                     100        MIN    -0.855
# 3  rnn-cell-3d-1498500240                     100  WSUM_EXPO    -0.515
# 1  rnn-cell-3d-1498497679                     100         OI    -0.780
# 2  rnn-cell-3d-1498499010                     100     SUMMIN    -9.592
# 4  rnn-cell-3d-1499502997                     100        SUM    -8.400
#
#    TestMin  TrainMin
# 0   -0.857    -0.892
# 3   -0.806    -0.832
# 1   -0.792    -0.815
# 2   -0.676    -0.725
# 4   -0.661    -0.706

# %% [markdown]
# # 4d Models

# %%
utils.extract_lstm_trained_output("4d-rbf")[show_columns].sort_values('TestMin')[:5]
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-4d-1498501447                     100        MIN    -0.925
# 2  rnn-cell-4d-1498504450                     100     SUMMIN   -13.298
# 1  rnn-cell-4d-1498502851                     100         OI    -0.872
# 3  rnn-cell-4d-1498505878                     100  WSUM_EXPO    -0.575
# 4  rnn-cell-4d-1499504253                     100        SUM   -12.286
#
#    TestMin  TrainMin
# 0   -0.927    -0.984
# 2   -0.889    -0.949
# 1   -0.886    -0.952
# 3   -0.881    -0.937
# 4   -0.869    -0.932

# %%
utils.extract_lstm_trained_output("4d-matern32")[show_columns].sort_values('TestMin')[:5]
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 2  rnn-cell-4d-1498510653                     100     SUMMIN   -11.939
# 3  rnn-cell-4d-1498512291                     100  WSUM_EXPO    -0.527
# 4  rnn-cell-4d-1499505674                     100        SUM   -10.881
# 0  rnn-cell-4d-1498507303                     100        MIN    -0.887
# 1  rnn-cell-4d-1498508890                     100         OI    -0.858
#
#    TestMin  TrainMin
# 2   -0.917    -0.992
# 3   -0.915    -0.974
# 4   -0.897    -0.973
# 0   -0.890    -0.956
# 1   -0.877    -0.931

# %% [markdown]
# # 6d Models

# %%
utils.extract_lstm_trained_output("6d-rbf")[show_columns].sort_values('TestMin')[:5]
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-6d-1498513910                     100        MIN    -0.995
# 1  rnn-cell-6d-1498515319                     100         OI    -0.940
# 2  rnn-cell-6d-1498516915                     100     SUMMIN   -12.555
# 4  rnn-cell-6d-1499507104                     100        SUM   -10.991
# 3  rnn-cell-6d-1498518358                     100  WSUM_EXPO    -0.505
#
#    TestMin  TrainMin
# 0   -1.002    -1.097
# 1   -0.948    -1.056
# 2   -0.928    -1.042
# 4   -0.855    -1.015
# 3   -0.851    -0.992

# %%
utils.extract_lstm_trained_output("6d-matern32")[show_columns].sort_values('TestMin')[:5]
# Out:
#                 RNN Scope  Number of hidden Units       Loss  TestLoss  \
# 0  rnn-cell-6d-1498519779                     100        MIN    -1.060
# 3  rnn-cell-6d-1498524767                     100  WSUM_EXPO    -0.471
# 1  rnn-cell-6d-1498521376                     100         OI    -0.905
# 4  rnn-cell-4d-1499505674                     100        SUM   -10.881
# 5  rnn-cell-6d-1499508613                     100        SUM    -8.841
#
#    TestMin  TrainMin
# 0   -1.069    -1.328
# 3   -1.020    -1.243
# 1   -0.946    -1.078
# 4   -0.897    -0.973
# 5   -0.856    -1.089
